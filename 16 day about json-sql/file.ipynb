# %% [markdown]
# # Working with JSON

# %%
import pandas as pd

# %%
df = pd.read_json('test.json')

# %%
df
# Out:
#          id                                        ingredients
# 0     18009  [baking powder, eggs, all-purpose flour, raisi...
# 1     28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2     41580  [sausage links, fennel bulb, fronds, olive oil...
# 3     29752  [meat cuts, file powder, smoked sausage, okra,...
# 4     35687  [ground black pepper, salt, sausage casings, l...
# ...     ...                                                ...
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...
#
# [9944 rows x 2 columns]

# %%
# if there is a api url of a dataset of json then we load into the data frame through this code 
dff = pd.read_json('url')

# %% [markdown]
# # Working with SQL

# %%
# pip install mysql.connector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
mysql.connector.connect('world.sql')
# see the remaining code from the youtube campusx day 16 of 100 days ml , i have not complete the code here because i need to download the xampp application
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mysql.connector.connect('world.sql')
#       2 # see the remaining code from the youtube campusx day 16 of 100 days ml , i have not complete the code here because i need to download the xampp application
#
# File /opt/anaconda3/envs/env1/lib/python3.14/site-packages/mysql/connector/__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File /opt/anaconda3/envs/env1/lib/python3.14/site-packages/mysql/connector/connection.py:57, in MySQLConnection.__init__(self, *args, **kwargs)
#      55 self._socket = None
#      56 self._handshake = None
# ---> 57 super(MySQLConnection, self).__init__(*args, **kwargs)
#      59 self._converter_class = MySQLConverter
# ...
